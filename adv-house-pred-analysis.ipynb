# %% [markdown]
# # This is a notebook for House price detection and Analysis

# %% [markdown]
# Steps we follow:
# 1. Exploratory Data Analysis
# 2. Feature Engineering
# 3. Feature Selection
# 4. Model Building
# 5. Model Deployment

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/kaggle/input/regression-technique-eda/House Price Regression Tecnique/train.csv")
mydf=df

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# Here we try to find all the columns having null values and their percentage (this can also be done by df.isnull().sum() )

# %%
null_val=[i for i in df.columns if df[i].isnull().sum()>1]
for i in null_val:
    print(i,np.round(df[i].isnull().mean(),4))
# Out:
# LotFrontage 0.1774
# Alley 0.9377
# MasVnrType 0.5973
# MasVnrArea 0.0055
# BsmtQual 0.0253
# BsmtCond 0.0253
# BsmtExposure 0.026
# BsmtFinType1 0.0253
# BsmtFinType2 0.026
# FireplaceQu 0.4726
# GarageType 0.0555
# GarageYrBlt 0.0555
# GarageFinish 0.0555
# GarageQual 0.0555
# GarageCond 0.0555
# PoolQC 0.9952
# Fence 0.8075
# MiscFeature 0.963

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# In this step we are grouping all the null value col with SalePrice and plotting them

# %%
for i in null_val:
    data=df.copy()
    data[i]=np.where(data[i].isnull(),1,0)
    data.groupby(i)['SalePrice'].median().plot.bar()
    plt.title(i)
    plt.show()

# %% [markdown]
# Here we are finding the numerical valued columns from main dataset

# %%
num_val=[i for i in df.columns if df[i].dtypes!='O']
len(num_val)
df[num_val].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %% [markdown]
# Here the Columns which consist 'Year' values are segregated

# %%
year_val=[i for i in num_val if 'Year' in i or 'Yr' in i]
year_val
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
df.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel("year sold")
plt.ylabel("median house price")
plt.title("house price vs year sold")
# Out:
# Text(0.5, 1.0, 'house price vs year sold')

# %% [markdown]
# Except YrSold remaining all year columns are plotted against SalePrice with year diff value

# %%
for i in year_val:
    if i!='YrSold':
        data=df.copy()
        data[i]=data['YrSold']-data[i]
        plt.scatter(df[i],df['SalePrice'])
        plt.xlabel(i)
        plt.ylabel("SalePrice")
        plt.show()

# %% [markdown]
# In this step we are finding the discrete columns and analysing them against the SalePrice

# %%
discrete_val=[i for i in num_val if len(df[i].unique())<25 and i not in year_val]
print(len(discrete_val))
discrete_val
# Out:
# 17
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
for i in discrete_val:
    data=df.copy()
    data.groupby(i)['SalePrice'].median().plot.bar()
    plt.xlabel('Feature')
    plt.ylabel('SalePrice')
    plt.title('Comparison b/w Feature and SalePrice')
    plt.show()

# %% [markdown]
# Same as the above step but for continuous valued columns against SalePrice

# %%
continuous_val=[i for i in num_val if i not in discrete_val+year_val+['Id']]
print(len(continuous_val))
continuous_val
# Out:
# 16
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %% [markdown]
# Here we are using histograms to visualize the distribution of continuous values

# %%
for i in continuous_val:
    data=df.copy()
    plt.hist(x=i,data=data,bins=25)
    plt.xlabel(i)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# From the above plotted graphs it is clear that even though we are dealing with continuous values but we are not able to analyse them properly because except 'SalePrice' remaining all other plots have discontinues distribution. so thats the reason we are using "Logarithm Transformation"  on remaining continuous columns values.

# %%
for i in continuous_val:
    data=df.copy()
    if 0 in data[i].unique():
        pass
    else:
        data[i]=np.log(data[i])
        data['SalePrice']=np.log(data['SalePrice'])
        plt.scatter(x=data[i],y=data['SalePrice'])
        plt.xlabel(i)
        plt.ylabel('SalePrice')
        plt.show()

# %% [markdown]
# To identify the Outliers in above log tranformated distributions we use boxplot to verify and analyze

# %%
for i in continuous_val:
    data=df.copy()
    if 0 in data[i].unique():
        pass
    else:
        data[i]=np.log(data[i])
        plt.boxplot(x=i,data=data)
        plt.title(i)
        plt.show()

# %% [markdown]
# Here we are trying to find the categorical values and the no of unique values present in each of them

# %%
cat_val=[i for i in df.columns if df[i].dtypes=='O']
print(len(cat_val))
dfcat=df[cat_val]
for i in cat_val:
    print("{} {}".format(i,len(df[i].unique())))
# Out:
# 43
# MSZoning 5
# Street 2
# Alley 3
# LotShape 4
# LandContour 4
# Utilities 2
# LotConfig 5
# LandSlope 3
# Neighborhood 25
# Condition1 9
# Condition2 8
# BldgType 5
# HouseStyle 8
# RoofStyle 6
# RoofMatl 8
# Exterior1st 15
# Exterior2nd 16
# MasVnrType 4
# ExterQual 4
# ExterCond 5
# Foundation 6
# BsmtQual 5
# BsmtCond 5
# BsmtExposure 5
# BsmtFinType1 7
# BsmtFinType2 7
# Heating 6
# HeatingQC 5
# CentralAir 2
# Electrical 6
# KitchenQual 4
# Functional 7
# FireplaceQu 6
# GarageType 7
# GarageFinish 4
# GarageQual 6
# GarageCond 6
# PavedDrive 3
# PoolQC 4
# Fence 5
# MiscFeature 5
# SaleType 9
# SaleCondition 6

# %% [markdown]
# In this step we will visualize the variation of categorical values against SalePrice

# %%
for i in cat_val:
    data=df.copy()
    data.groupby(i)['SalePrice'].median().plot.bar()
    plt.xlabel(i)
    plt.ylabel('SalePrice')
    plt.show()

# %%
dfcat.head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
# ...

# %%
sns.heatmap(data=dfcat.isnull(),cmap='viridis',cbar=False,yticklabels=False)
# Out:
# <Axes: >

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# From here onwards I am using 'mydf' as my new dataset besides 'df' because there is some issue that gets changed in df so i make mydf=df and using mydf as my new original dataset.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df,df['SalePrice'],test_size=0.3,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((1022, 81), (438, 81))

# %% [markdown]
# Here we will find the null values present in categorical values and try to replace these missing values

# %%
features_nan=[feature for feature in mydf.columns if mydf[feature].isnull().sum()>1 and mydf[feature].dtypes=='O']

for feature in features_nan:
    print("{}: {}% missing values".format(feature,np.round(mydf[feature].isnull().mean(),4)))
# Out:
# Alley: 0.9377% missing values
# MasVnrType: 0.5973% missing values
# BsmtQual: 0.0253% missing values
# BsmtCond: 0.0253% missing values
# BsmtExposure: 0.026% missing values
# BsmtFinType1: 0.0253% missing values
# BsmtFinType2: 0.026% missing values
# FireplaceQu: 0.4726% missing values
# GarageType: 0.0555% missing values
# GarageFinish: 0.0555% missing values
# GarageQual: 0.0555% missing values
# GarageCond: 0.0555% missing values
# PoolQC: 0.9952% missing values
# Fence: 0.8075% missing values
# MiscFeature: 0.963% missing values

# %% [markdown]
# Here this is a new and very different step because here we will try to replace the missing values with some label(here 'missing') so that all the missing values will get chnaged to 'missing' then after this step we will try to find what the value of 'missing' label should be to procedd

# %%
def replace_cat_feature(mydf,features_nan):
    data=mydf.copy()
    data[features_nan]=data[features_nan].fillna('Missing')
    return data

mydf=replace_cat_feature(mydf,features_nan)

mydf[features_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
mydf.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities  ... PoolArea   PoolQC    Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0  Missing  Missing     Missing       0
# 1         Lvl    AllPub  ...        0  Missing  Missing     Missing       0
# 2         Lvl    AllPub  ...        0  Missing  Missing     Missing       0
# 3         Lvl    AllPub  ...        0  Missing  Missing     Missing       0
# 4         Lvl    AllPub  ...        0  Missing  Missing     Missing       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# In this step we will try to find the missing values in numerical valued columns and follow the same procedure as above

# %%
numerical_with_nan=[feature for feature in mydf.columns if mydf[feature].isnull().sum()>1 and mydf[feature].dtypes!='O']
for feature in numerical_with_nan:
    print("{}: {}% missing value".format(feature,np.around(mydf[feature].isnull().mean(),4)))
# Out:
# LotFrontage: 0.1774% missing value
# MasVnrArea: 0.0055% missing value
# GarageYrBlt: 0.0555% missing value

# %% [markdown]
# But instead of 'missing' label here we will use either '1' or '0' because of numerical columns

# %%
for feature in numerical_with_nan:
    median_value=mydf[feature].median()
    mydf[feature+'nan']=np.where(mydf[feature].isnull(),1,0)
    mydf[feature].fillna(median_value,inplace=True)
    
mydf[numerical_with_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
mydf.head(50)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave  Missing      Reg
# 1    2          20       RL         80.0     9600   Pave  Missing      Reg
# 2    3          60       RL         68.0    11250   Pave  Missing      IR1
# 3    4          70       RL         60.0     9550   Pave  Missing      IR1
# 4    5          60       RL         84.0    14260   Pave  Missing      IR1
# 5    6          50       RL         85.0    14115   Pave  Missing      IR1
# 6    7          20       RL         75.0    10084   Pave  Missing      Reg
# 7    8          60       RL         69.0    10382   Pave  Missing      IR1
# 8    9          50       RM         51.0     6120   Pave  Missing      Reg
# 9   10         190       RL         50.0     7420   Pave  Missing      Reg
# 10  11          20       RL         70.0    11200   Pave  Missing      Reg
# ...

# %% [markdown]
# Now we perform temporal values for date time variables

# %%
for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:     
    mydf[feature]=mydf['YrSold']-mydf[feature]

# %%
mydf.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...     Missing       0      2   2008       WD
# 1         Lvl    AllPub  ...     Missing       0      5   2007       WD
# 2         Lvl    AllPub  ...     Missing       0      9   2008       WD
# 3         Lvl    AllPub  ...     Missing       0      2   2006       WD
# 4         Lvl    AllPub  ...     Missing       0     12   2008       WD
#
#   SaleCondition SalePrice  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# ...

# %%
mydf[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %%
continuous_val
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %% [markdown]
# Here we will convert the numerical continuous column values into log values through normal log transformation where the column values should not have '0' in it.

# %%
import numpy as np
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']
for feature in num_features:
    mydf[feature]=np.log(mydf[feature])

# %%
mydf.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1   2          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2   3          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3   4          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4   5          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...     Missing       0      2   2008       WD
# 1         Lvl    AllPub  ...     Missing       0      5   2007       WD
# 2         Lvl    AllPub  ...     Missing       0      9   2008       WD
# 3         Lvl    AllPub  ...     Missing       0      2   2006       WD
# 4         Lvl    AllPub  ...     Missing       0     12   2008       WD
#
#   SaleCondition  SalePrice  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# ...

# %%
print(len(cat_val))
cat_val
# Out:
# 43
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for i in cat_val:
    temp=mydf.groupby(i)['SalePrice'].count()/len(mydf)
    temp_df=temp[temp>0.01].index
    mydf[i]=np.where(mydf[i].isin(temp_df),mydf[i],'Rare_var')

# %%
mydf.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1   2          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2   3          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3   4          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4   5          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...     Missing       0      2   2008       WD
# 1         Lvl    AllPub  ...     Missing       0      5   2007       WD
# 2         Lvl    AllPub  ...     Missing       0      9   2008       WD
# 3         Lvl    AllPub  ...     Missing       0      2   2006       WD
# 4         Lvl    AllPub  ...     Missing       0     12   2008       WD
#
#   SaleCondition  SalePrice  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# ...

# %%
for i in cat_val:
    label_order=mydf.groupby([i])['SalePrice'].mean().sort_values().index
    label_order={k:j for j,k in enumerate(label_order,0)}
    mydf[i]=mydf[i].map(label_order)

# %%
scalecolumn=[i for i in mydf.columns if i not in ['Id','SalePrice']]
print(len(scalecolumn))
scalecolumn
# Out:
# 82
# ['MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
mydf.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1          60         3     4.174387  9.041922       1      2         0
# 1   2          20         3     4.382027  9.169518       1      2         0
# 2   3          60         3     4.219508  9.328123       1      2         1
# 3   4          70         3     4.094345  9.164296       1      2         1
# 4   5          60         3     4.430817  9.565214       1      2         1
#
#    LandContour  Utilities  ...  MiscFeature  MiscVal  MoSold  YrSold  \
# 0            1          1  ...            2        0       2    2008
# 1            1          1  ...            2        0       5    2007
# 2            1          1  ...            2        0       9    2008
# 3            1          1  ...            2        0       2    2006
# 4            1          1  ...            2        0      12    2008
#
#    SaleType  SaleCondition  SalePrice  LotFrontagenan  MasVnrAreanan  \
# ...

# %% [markdown]
# **In this step we will try to implement "Feature Scaling" procedure**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(mydf[scalecolumn])
# Out:
# MinMaxScaler()

# %%
 scaler.transform(mydf[scalecolumn])
# Out:
# array([[0.23529412, 0.75      , 0.41820812, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.49506375, ..., 0.        , 0.        ,
#         0.        ],
#        [0.23529412, 0.75      , 0.434909  , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.29411765, 0.75      , 0.42385922, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.434909  , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.47117546, ..., 0.        , 0.        ,
#         0.        ]])

# %%
data = pd.concat([mydf[['Id', 'SalePrice']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(mydf[scalecolumn]), columns=scalecolumn)],
                    axis=1)
data.head()
# Out:
#    Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0   1  12.247694    0.235294      0.75     0.418208  0.366344     1.0    1.0
# 1   2  12.109011    0.000000      0.75     0.495064  0.391317     1.0    1.0
# 2   3  12.317167    0.235294      0.75     0.434909  0.422359     1.0    1.0
# 3   4  11.849398    0.294118      0.75     0.388581  0.390295     1.0    1.0
# 4   5  12.429216    0.235294      0.75     0.513123  0.468761     1.0    1.0
#
#    LotShape  LandContour  ...  Fence  MiscFeature  MiscVal    MoSold  YrSold  \
# 0  0.000000     0.333333  ...    1.0          1.0      0.0  0.090909    0.50
# 1  0.000000     0.333333  ...    1.0          1.0      0.0  0.363636    0.25
# 2  0.333333     0.333333  ...    1.0          1.0      0.0  0.727273    0.50
# 3  0.333333     0.333333  ...    1.0          1.0      0.0  0.090909    0.00
# 4  0.333333     0.333333  ...    1.0          1.0      0.0  1.000000    0.50
#
# ...

# %% [markdown]
# Now we copy this perfect data for further data analysis as a train_csv file.

# %%
data.to_csv("x_train.csv",index=False)

# %% [markdown]
# Now we will use this x_train file for "Feature Selection" Process

# %% [markdown]
# # Feature Selection

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import SelectFromModel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[107], line 2
#       1 from sklearn.linear_model import Lasso
# ----> 2 from sklearn.model_selection import SelectFromModel
#
# ImportError: cannot import name 'SelectFromModel' from 'sklearn.model_selection' (/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/__init__.py)
